# %% [markdown]
# ## **9 Optimización**

# %% [markdown]
# ### **9.1 Extremos absolutos de funciones de una variable**

# %% [markdown]
# #### **9.1.1 Determinación de los extremos absolutos de una función continua en un intervalo cerrado**

# %% [markdown]
# #### **9.1.2 Problemas de optimización en una variable**

# %% [markdown]
# ### **9.2 Extremos en varias variables**

# %% [markdown]
# #### **9.2.1 Extremos locales**

# %% [markdown]
# #### **9.2.2 Extremos absolutos**

# %% [markdown]
# #### **9.2.3 Método de los multiplicadores de Lagrange**
