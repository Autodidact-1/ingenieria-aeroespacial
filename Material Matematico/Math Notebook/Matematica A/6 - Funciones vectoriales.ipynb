# %% [markdown]
# ## **6 Funciones vectoriales**

# %% [markdown]
# ### **6.1 Vectores en el plano y en el espacio**

# %% [markdown]
# #### **6.1.1 Vectores y desplazamientos**

# %% [markdown]
# #### **6.1.2 Operaciones entre vectores**

# %% [markdown]
# #### **6.1.3 Vectores en coordenadas polares**

# %% [markdown]
# #### **6.1.4 Vectores en el espacio. Coordenadas en $\mathbb{R}^3$**

# %% [markdown]
# ### **6.2 El producto punto**

# %% [markdown]
# #### **6.2.1 El ángulo entre dos vectores**

# %% [markdown]
# #### **6.2.2 El producto punto**

# %% [markdown]
# ### **6.3 Ecuaciones de las rectas y los planos**

# %% [markdown]
# #### **6.3.1 Ecuación vectorial de una recta**

# %% [markdown]
# #### **6.3.2 Ecuación implicita de un plano en el espacio**

# %% [markdown]
# ### **6.4 Funciones a valores vectoriales**

# %% [markdown]
# #### **6.4.1 Curvas parametrizadas**

# %% [markdown]
# #### **6.4.2 Sentido de recorrido**

# %% [markdown]
# #### **6.4.3 Movimiento en el espacio. Funciones a valores vectoriales**

# %% [markdown]
# #### **6.4.4 La dericada de una función vectorial**
